# %%
#classes and pointers

class Cookie:
    def __init__(self,color):
        self.color= color
        
    def get_color(self):
        return self.color
    def set_color(self,color):
        self.color = color
        
cookie_one = Cookie('green')
print(cookie_one.get_color())
# Out:
# green

# %%
# class LinkedList:
#     def __init__(self,value):
    
#     def append(self,value):
    
#     def pop(self):
        
#     def prepend(self, value):
        
#     def inser(self,index, value):
        
#     def remove(self,index):

# %%
head  ={
    'value':23,  #head node
    'next' : {
        'value' : 32,
        'next' : {
            'value' : 45,  #tail node
            'next' : None
        }
    }
         
}

# %%
print(head['next']['next']['value'])
# Out:
# 45

# %%
class Node:
    def __init__ (self,value):       #constructor
        self.value = value   #value
        self.next = None     #next node
        
class LinkedList:
    def __init__ (self,value):   #constructor
        new_node = Node    #assaining node to the new node
        self.head = new_node  #head is assained to the new node
        self.tail = new_node   #tail is assained to the new node
        self.length = 1         #for traking the leangth we assained one

# %%
my_linked_list = LinkedList(4)
print(my_linked_list.head.value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13124\2967110636.py in <module>
# ----> 1 my_linked_list = LinkedList(4)
#       2 print(my_linked_list.head.value)
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1
        
    def print_item(self):
        temp = self.head
        while head is not None:
            print(temp.value)
            temp = temp.next
        
    def append(self,value):
        new_node = Node(value)
        if Node is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length = +1

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1
    def print_item(self):
        temp = self.head
        while temp is not None:
            print(temp.value)
            temp = temp.next
    def append(self,value):
        new_node = Node(value)
        if Node is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
            
        self.length = +1
        
    def pop(self):
        if self.length == 0:
            return None
        temp = self.head
        pre = self.head
        while temp.next:
            pre = temp
            temp= temp.next
        pre = self.tail
        self.tail.next = None
        self.length -=1
        if self.length == 0:
            self.temp = None
            self.tail = None
            
        return temp
    def prepend(self,value):
        new_node = Node(value)
        if self.length == 0:
            self.head= new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1
        return None
            
    def pop_first(self):
        if self.length == 0:
            return None
        temp = self.head
        temp.next = self.head
        temp.next = None
        self.length -= 1
        if self.length == 0:
            self.tail = None
            
        return None
    
    def get(self,index):
        if index < 0 or  index <= self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
        return temp.value
    
    def set_value(self,index,value):
        temp = self.get(index)
        if temp is not None:
            temp.value = value
            return True
        return False
    
    def insert(self,index,value):
        if index < 0 or index >self.length:
            return False
        if index == 0:
            return self.prepend(value)
        if index == self.length:
            return self.append(value)
        new_node = Node(value)
        temp = self.get(index - 1)
        new_node.next = temp.next
        temp.next = new_node
        self.length += 1
        return True
        
    def remove(self,index):
        if index < 0 or index > self.length:
            return False
        if index == 0:
            return self.pop_first()
        if index == self.length:
            return self.pop()
        pre = self.get(index-1)
        temp = pre.next
        pre.next = temp.next
        temp.next = None
        self.length -=1
        return True

    
    def reverse (self):
        temp = self.head
        self.head = self.tail
        self.tail = temp
        temp.next = after
        before = None
        for _ in range(self.length):
            after = temp.next
            temp.next = before
            before = temp
            temp = after

# %%
my_linked_list = LinkedList(2)
my_linked_list.append(3)
my_linked_list.append(4)
my_linked_list.append(5)
#my_linked_list.append(6)
#my_linked_list.append(7)
#my_linked_list.prepend(20)
my_linked_list.print_item()
#my_linked_list.pop_first()

print(my_linked_list.get(2))
# Out:
# 2
# 3
# 4
# 5
# None

# %%
print(my_linked_list)
# Out:
# <__main__.LinkedList object at 0x000001DAC988D130>

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1
        
    def print_item(self):
        temp = self.head
        if temp is not None:
            print(temp.value)
            temp = temp.next  
            
    def append(self,value):
        new_node = Node(value)
        if Node is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
            
        self.length += 1
        return None
        
    def pop(self):
        if self.length == 0:
            return None
        
        temp = self.head
        pre = self.head
        
        while temp.next:
            pre = temp
            temp= temp.next
            
        pre = self.tail
        self.tail.next = None
        self.length -= 1
        if self.length == 0:
            self.temp = None
            self.tail = None
        return temp
    
    def prepend(self,value):
        new_node = Node(value)
        if self.length == 0:
            return None
        else:
            new_node.next = self.head
            new_node = self.head
            
        return None
    
    def pop_first(self):
        if self.length == 0:
            return None
        
        temp = self.head
        self.head.next = self.head
        self.temp = None
        self.length -= 1
        if self.length == 0:
            self.tail = None
        
        return temp
            
    def get(self,index,value):
        if index <0 or index>= self.length:
            return None
        
        temp = self.head
        for _ in range(index):
            temp = temp.next
            
        return temp.value

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1
        
    def print_item(self):
        temp = self.head
        while temp is not None:
            print(temp.value)
            temp = temp.next
            
    def append(self,value):
        if self.length == 0:
            self.head = new_node
            self.tail = new_node
            
        else:
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1
        return None
    def prepend(self,value):
        if self.length == 0:
            self.head = new_node
            self.tail = new_node
            
        else:
            new_node.next = self.head
            self.head = new_node
            
        self.length += 1
        return None
    def pop(self):
        if self.length == 0:
            return None
        temp = self.head
        pre = self.head
        while temp.next:
            pre = temp
            temp = temp.next
        pre = self.tail
        self.tail.next = None
        self.length -= 1
        if self.length == 0:
            self.temp = None
            self.pre = None
        return None
    
    def pop_first(self):
        if self.length == 0:
            return None
        temp = self.head
        self.head = self.head.next
        temp.next = None
        self.length -= 1
        if self.length == 0:
            self.tail = None
        return temp
    def get(self,index):
        if index < 0 or index >= self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
        return temp
    def set_value(self,index,value):
        new_node = Node(value)
        temp = self.get(index)
        if temp is not None:
            temp.value = value
            return True
        return False
    def insert(self,index,value):
        if index < 0 or index >self.length :
            return False
        if index == 0:
            return self.prepend(value)
        if index == self.length:
            return self.append(value)
        new_node = Node(value)
        temp = self.get(index-1)
        new_node.next = temp.next
        temp.next = new_node
        self.length += 1
        return True
    def remove (self,index):
        if index < 0 or index >self.length:
            return False
        if index == 0:
            return pop_first()
        if index == self.length:
            return pop()
        pre= self.get(index-1)
        pre.next = temp
        pre.next = temp.next
        temp.next = None
        return True
    def reverse (self):
        temp = self.head
        self.head = self.tail
        self.tail = temp
        after = temp.next
        before = None
        for _ in range(self.length):
            after = temp.next
            temp.next = before
            befor = temp
            temp = after

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        self.prev = None
        
class DoubleLinkedList:
    def __init__(self,value):
        new_node = Node(value)
        self.head = Node
        self.tail = Node
        self.length = 1
        
    def print_item(self):
        temp = self.head
        while temp is not None:
            print(temp.value)
            temp = temp.next
            
    def append(self,value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        self.length += 1
        return None
    
    def pop(self):
        if self.length == 0:
            return None
        temp = self.tail
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.tail = self.tail.next
            self.tail.next = None
            temp.prev = None
            self.length -=1
        return temp
            
        def prepend(self,value):
            new_node = Node(value)
            if self.length == 0:
                self.head = new_node
                self.tail = new_node
            else:
                new_node.next = self.head
                self.head.prev = new_node
                self.head = new_node
            self.length += 1
            return None
        def pop_first(self):
            if self.length == 0:
                return None
            temp = self.head
            if self.length == 1:
                self.head = None
                self.tail = None
            else:
                self.head = self.head.next
                temp.next = None
                self.head.prev = None
            self.lenght -= 1
            return temp
        def get(self,index):
            if index < 0 or index >= self.length:
                return None
            temp = self.head
            if index < self.length / 2:
                for _ in range(index):
                    temp = temp.next
            else :
                temp = self.tail
                for _ in range(self.length -1,index,-1):
                    temp = temp.prev
            return temp
        
        def set_value(self,index,value):
            temp = self.get(index)
            if temp is not None:
                temp.value = value
                return True
            return False
        
        
        def insert (self,index,value):
            if index < 0 or index > self.length:
                return False
            if index == 0:
                return self.prepend(value)
            if index  == self.length:
                return self.append(value)
            new_node = Node(value)
            temp = self.get(index-1)
            pre = temp.next
            temp.next = new_node.next
            pre.prev = new_node
            #new_node.prev = temp
            #new_node.next = pre
            temp.next = new_node
            new_node.prev = temp
            self.length += 1
            return True

# %%
my_linked_list = DoubleLinkedList(5)
my_linked_list.append(5)

my_linked_list.print_item()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17396\161382328.py in <module>
# ----> 1 my_linked_list = DoubleLinkedList(5)
#       2 my_linked_list.append(5)
#       3
#       4 my_linked_list.print_item()
#
# NameError: name 'DoubleLinkedList' is not defined

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList:
    def __init__(self,value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1
        
    def print_item(self):
        temp = self.head
        while temp is not None:
            print(temp.value)
            temp = temp.next
    def append(self,value):
        if self.length == 0:
            self.head = new_node
            self.tail = new_node
        else:
            new_node = Node(value)
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1
        return None
    def pop (self):
        if self.length == 0:
            return None
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            temp = self.head
            pre= self.head
            while temp.next:
                pre = temp
                temp = temp.next
            pre = self.tail
            self.tail.next = None
            self.length-=1
        return temp.value
    def prepend(self,value):
        if self.length == 0:
            self.head = new_node
            self.tail = new_node
        else:
            new_node = Node(value)
            new_node.next = self.head
            self.head = new_node
            self.length += 1
        return None
    
    def get(self,index):
        if index < 0 or index >= self.length:
            return None
        temp = self.head
        for _ in range(index):
            temp = temp.next
            return temp.value
        
    def set_

# %%
my_linked_list= LinkedList(1)
my_linked_list.append(3)
my_linked_list.append(4)
my_linked_list.append(8)
my_linked_list.append(9)
my_linked_list.append(8)
my_linked_list.prepend(4)

my_linked_list.print_item()
print(my_linked_list.get(2))
# Out:
# 4
# 1
# 3
# 4
# 8
# 9
# 8
# 1
